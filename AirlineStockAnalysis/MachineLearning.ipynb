# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#read the csv file
stocks = pd.read_csv("data/Final_Collective_Dataset.csv")
stocks.head()
# Out:
#          Date  UAL_Close  UAL_Volume  UAL_Open  UAL_High  UAL_Low  DAL_Close  \
# 0  2020-12-31      43.25  12683980.0    44.410   44.5617    43.11      40.21
# 1  2020-12-30      44.65   9473270.0    43.635   44.7600    43.46      40.56
# 2  2020-12-29      43.74   9927674.0    44.450   44.6489    43.55      40.03
# 3  2020-12-28      43.92  13693200.0    44.035   44.6250    43.75      40.15
# 4  2020-12-24      43.26   7230607.0    44.400   44.4165    43.01      39.73
#
#    DAL_Volume  DAL_Open  DAL_High  ...  LUV_High  LUV_Low  SAVE_Close  \
# 0   8705736.0     40.30   40.7400  ...     46.78   45.680       24.45
# 1   8504632.0     40.00   40.9050  ...     46.93   46.125       24.87
# 2   8142801.0     40.84   40.8400  ...     46.77   45.970       24.68
# 3  10654380.0     40.27   40.7758  ...     47.17   46.110       25.07
# 4   5176408.0     40.42   40.4400  ...     47.09   45.810       24.42
#
#    SAVE_Volume  SAVE_Open  SAVE_High  SAVE_Low  Year  Month  Day
# 0    3548551.0      24.70    24.8914   24.2100  2020     12   31
# 1    3427572.0      24.62    25.3400   24.5600  2020     12   30
# 2    3917613.0      25.42    25.5700   24.5200  2020     12   29
# 3    4295602.0      24.96    25.4700   24.6202  2020     12   28
# 4    2618194.0      24.79    24.8300   24.0540  2020     12   24
#
# [5 rows x 34 columns]

# %%
#determine the shape of the data
print("training days =", stocks.shape)
# Out:
# training days = (756, 34)

# %% [markdown]
# # United Airlines

# %%
#creating initial plot of United Airlines Closing prices as of Dec 31, 2020
sns.set()
plt.figure(figsize=(10, 4))

#create labels
plt.title("United Airlines'Stock Price")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(stocks["UAL_Close"])

#save to png
plt.savefig("images/originalcloseUAL.png")

#display chart
plt.show()

# %%
#pulling the array of close prices
close = stocks[["UAL_Close"]]
close.head()
# Out:
#    UAL_Close
# 0      43.25
# 1      44.65
# 2      43.74
# 3      43.92
# 4      43.26

# %%
#creating a variable for the number of future days predicted
futureDays = 65

# %%
#creating a new column to hold the predicted values of close prices
close["Prediction"] = stocks[["UAL_Close"]].shift(-futureDays)
print(close.head())
print(close.tail())
# Out:
#    UAL_Close  Prediction
# 0      43.25       34.51
# 1      44.65       35.94
# 2      43.74       34.20
# 3      43.92       32.74
# 4      43.26       33.08
#      UAL_Close  Prediction
# 751      68.51         NaN
# 752      69.36         NaN
# 753      69.26         NaN
# 754      68.49         NaN
# 755      68.94         NaN
# <ipython-input-7-54dc9c3dd306>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close["Prediction"] = stocks[["UAL_Close"]].shift(-futureDays)

# %%
#creating an array and removing the last rows
X = np.array(close.drop(["Prediction"], 1))[:-futureDays]
print(X)
# Out:
# [[43.25 ]
#  [44.65 ]
#  [43.74 ]
#  [43.92 ]
#  [43.26 ]
#  [44.11 ]
#  [42.97 ]
#  [44.055]
#  [44.74 ]
#  [45.88 ]
#  [46.   ]
#  [47.46 ]
#  [46.72 ]
#  [48.36 ]
#  [49.64 ]
#  [48.02 ]
#  [49.04 ]
#  [49.2  ]
#  [49.24 ]
#  [49.91 ]
#  [46.73 ]
#  [45.32 ]
#  [45.05 ]
#  [45.3  ]
#  [45.64 ]
#  [44.96 ]
#  [40.93 ]
#  [39.9  ]
#  [40.94 ]
#  [41.05 ]
#  [40.6  ]
#  [41.   ]
#  [38.99 ]
#  [36.85 ]
#  [38.51 ]
#  [40.05 ]
#  [41.32 ]
#  [34.68 ]
#  [35.35 ]
#  [33.34 ]
#  [34.02 ]
#  [33.78 ]
#  [33.86 ]
#  [33.57 ]
#  [32.6  ]
#  [34.17 ]
#  [35.34 ]
#  [38.01 ]
#  [37.24 ]
#  [35.54 ]
#  [36.06 ]
#  [35.5  ]
#  [34.16 ]
#  [34.25 ]
#  [35.61 ]
#  [35.26 ]
#  [36.38 ]
#  [37.12 ]
#  [37.   ]
#  [36.38 ]
#  [34.88 ]
#  [36.2  ]
#  [36.01 ]
#  [35.18 ]
#  [34.75 ]
#  [34.51 ]
#  [35.94 ]
#  [34.2  ]
#  [32.74 ]
#  [33.08 ]
#  [34.07 ]
#  [33.79 ]
#  [36.97 ]
#  [38.355]
#  [38.3  ]
#  [36.8  ]
#  [36.74 ]
#  [36.07 ]
#  [36.45 ]
#  [36.03 ]
#  [37.28 ]
#  [38.21 ]
#  [37.4  ]
#  [36.89 ]
#  [36.01 ]
#  [36.   ]
#  [37.34 ]
#  [36.22 ]
#  [34.25 ]
#  [35.22 ]
#  [36.32 ]
#  [33.04 ]
#  [34.05 ]
#  [34.44 ]
#  [33.98 ]
#  [34.4  ]
#  [36.18 ]
#  [35.81 ]
#  [36.4  ]
#  [36.83 ]
#  [37.54 ]
#  [34.33 ]
#  [34.4  ]
#  [33.73 ]
#  [32.29 ]
#  [31.87 ]
#  [31.38 ]
#  [31.74 ]
#  [32.57 ]
#  [33.46 ]
#  [32.42 ]
#  [32.88 ]
#  [33.23 ]
#  [31.67 ]
#  [33.07 ]
#  [32.33 ]
#  [33.92 ]
#  [34.49 ]
#  [36.37 ]
#  [31.74 ]
#  [31.76 ]
#  [32.67 ]
#  [30.17 ]
#  [32.53 ]
#  [32.55 ]
#  [35.21 ]
#  [34.14 ]
#  [34.45 ]
#  [34.61 ]
#  [35.27 ]
#  [32.89 ]
#  [34.69 ]
#  [33.07 ]
#  [36.08 ]
#  [36.54 ]
#  [36.84 ]
#  [39.34 ]
#  [39.25 ]
#  [40.21 ]
#  [39.   ]
#  [39.66 ]
#  [33.32 ]
#  [39.72 ]
#  [44.64 ]
#  [48.69 ]
#  [42.405]
#  [39.1  ]
#  [33.65 ]
#  [29.91 ]
#  [29.46 ]
#  [28.04 ]
#  [28.89 ]
#  [30.69 ]
#  [29.54 ]
#  [25.4  ]
#  [25.84 ]
#  [24.91 ]
#  [23.68 ]
#  [24.13 ]
#  [19.92 ]
#  [20.3  ]
#  [20.71 ]
#  [22.76 ]
#  [23.97 ]
#  [25.42 ]
#  [22.75 ]
#  [22.91 ]
#  [24.12 ]
#  [25.26 ]
#  [26.62 ]
#  [29.58 ]
#  [31.21 ]
#  [27.84 ]
#  [25.   ]
#  [25.56 ]
#  [25.72 ]
#  [25.88 ]
#  [27.88 ]
#  [27.79 ]
#  [29.08 ]
#  [28.21 ]
#  [31.86 ]
#  [30.9  ]
#  [28.91 ]
#  [31.5  ]
#  [27.51 ]
#  [24.48 ]
#  [24.02 ]
#  [22.885]
#  [23.42 ]
#  [25.65 ]
#  [31.55 ]
#  [30.16 ]
#  [32.84 ]
#  [35.55 ]
#  [36.6  ]
#  [33.   ]
#  [26.25 ]
#  [24.5  ]
#  [21.28 ]
#  [21.38 ]
#  [30.67 ]
#  [35.47 ]
#  [41.64 ]
#  [37.08 ]
#  [49.34 ]
#  [52.56 ]
#  [46.78 ]
#  [52.1  ]
#  [51.59 ]
#  [59.47 ]
#  [58.29 ]
#  [61.26 ]
#  [61.59 ]
#  [64.94 ]
#  [66.53 ]
#  [70.57 ]
#  [75.47 ]
#  [78.01 ]
#  [79.91 ]
#  [79.42 ]
#  [80.24 ]
#  [79.55 ]
#  [80.99 ]
#  [82.2  ]
#  [80.53 ]
#  [79.47 ]
#  [79.48 ]
#  [80.5  ]
#  [81.85 ]
#  [78.89 ]
#  [74.91 ]
#  [74.8  ]
#  [77.75 ]
#  [75.21 ]
#  [77.05 ]
#  [77.63 ]
#  [81.9  ]
#  [84.88 ]
#  [83.34 ]
#  [85.79 ]
#  [89.7  ]
#  [89.54 ]
#  [88.29 ]
#  [87.85 ]
#  [86.89 ]
#  [87.31 ]
#  [87.95 ]
#  [87.3  ]
#  [86.77 ]
#  [87.7  ]
#  [87.9  ]
#  [89.74 ]
#  [88.09 ]
#  [87.96 ]
#  [88.37 ]
#  [89.26 ]
#  [89.15 ]
#  [89.44 ]
#  [89.28 ]
#  [89.22 ]
#  [88.84 ]
#  [89.36 ]
#  [88.63 ]
#  [87.58 ]
#  [88.47 ]
#  [87.02 ]
#  [86.51 ]
#  [87.61 ]
#  [88.58 ]
#  [87.86 ]
#  [88.17 ]
#  [88.87 ]
#  [91.63 ]
#  [92.8  ]
#  [93.05 ]
#  [92.76 ]
#  [92.52 ]
#  [91.78 ]
#  [90.97 ]
#  [91.7  ]
#  [93.29 ]
#  [92.77 ]
#  [92.51 ]
#  [92.52 ]
#  [92.42 ]
#  [92.72 ]
#  [93.53 ]
#  [93.44 ]
#  [93.8  ]
#  [93.34 ]
#  [93.12 ]
#  [92.39 ]
#  [91.65 ]
#  [90.84 ]
#  [91.67 ]
#  [91.03 ]
#  [92.19 ]
#  [91.64 ]
#  [89.81 ]
#  [89.9  ]
#  [89.71 ]
#  [90.78 ]
#  [90.085]
#  [89.46 ]
#  [89.7  ]
#  [87.88 ]
#  [86.97 ]
#  [87.15 ]
#  [87.34 ]
#  [86.46 ]
#  [84.69 ]
#  [84.85 ]
#  [84.29 ]
#  [83.27 ]
#  [83.69 ]
#  [87.84 ]
#  [88.41 ]
#  [88.14 ]
#  [88.45 ]
#  [89.17 ]
#  [88.3  ]
#  [88.21 ]
#  [89.09 ]
#  [89.42 ]
#  [90.23 ]
#  [89.98 ]
#  [88.76 ]
#  [91.35 ]
#  [89.38 ]
#  [88.38 ]
#  [87.56 ]
#  [87.33 ]
#  [86.3  ]
#  [85.84 ]
#  [83.91 ]
#  [83.15 ]
#  [84.31 ]
#  [84.69 ]
#  [82.45 ]
#  [81.94 ]
#  [83.58 ]
#  [82.53 ]
#  [85.56 ]
#  [85.29 ]
#  [84.03 ]
#  [83.89 ]
#  [82.94 ]
#  [81.62 ]
#  [81.95 ]
#  [84.56 ]
#  [84.71 ]
#  [86.98 ]
#  [87.63 ]
#  [86.48 ]
#  [85.46 ]
#  [85.59 ]
#  [89.43 ]
#  [90.49 ]
#  [91.91 ]
#  [93.93 ]
#  [93.44 ]
#  [93.36 ]
#  [93.93 ]
#  [95.11 ]
#  [94.93 ]
#  [93.83 ]
#  [93.83 ]
#  [95.28 ]
#  [94.78 ]
#  [93.92 ]
#  [91.32 ]
#  [91.23 ]
#  [89.48 ]
#  [89.51 ]
#  [89.46 ]
#  [90.67 ]
#  [90.59 ]
#  [90.67 ]
#  [88.87 ]
#  [88.45 ]
#  [87.55 ]
#  [86.43 ]
#  [85.33 ]
#  [85.06 ]
#  [86.55 ]
#  [86.72 ]
#  [87.14 ]
#  [88.66 ]
#  [87.4  ]
#  [86.77 ]
#  [87.12 ]
#  [87.11 ]
#  [83.79 ]
#  [82.77 ]
#  [82.67 ]
#  [83.27 ]
#  [82.96 ]
#  [81.85 ]
#  [80.52 ]
#  [77.72 ]
#  [77.65 ]
#  [79.47 ]
#  [79.25 ]
#  [79.81 ]
#  [80.79 ]
#  [80.91 ]
#  [81.88 ]
#  [82.97 ]
#  [81.74 ]
#  [81.5  ]
#  [82.58 ]
#  [82.35 ]
#  [83.45 ]
#  [82.07 ]
#  [84.79 ]
#  [84.12 ]
#  [84.64 ]
#  [85.68 ]
#  [87.79 ]
#  [88.5  ]
#  [88.31 ]
#  [87.94 ]
#  [88.86 ]
#  [89.61 ]
#  [87.94 ]
#  [86.86 ]
#  [88.03 ]
#  [87.97 ]
#  [87.56 ]
#  [88.28 ]
#  [89.24 ]
#  [85.17 ]
#  [84.52 ]
#  [85.49 ]
#  [85.75 ]
#  [84.52 ]
#  [84.25 ]
#  [84.58 ]
#  [84.91 ]
#  [84.64 ]
#  [84.2  ]
#  [82.77 ]
#  [80.87 ]
#  [79.78 ]
#  [78.6  ]
#  [78.53 ]
#  [77.49 ]
#  [78.12 ]
#  [79.63 ]
#  [81.   ]
#  [79.83 ]
#  [81.34 ]
#  [80.73 ]
#  [81.69 ]
#  [81.49 ]
#  [81.21 ]
#  [79.85 ]
#  [82.38 ]
#  [82.4  ]
#  [82.61 ]
#  [84.33 ]
#  [85.05 ]
#  [84.31 ]
#  [86.92 ]
#  [87.81 ]
#  [87.6  ]
#  [89.53 ]
#  [89.58 ]
#  [89.43 ]
#  [88.84 ]
#  [88.5  ]
#  [89.24 ]
#  [88.31 ]
#  [88.15 ]
#  [88.58 ]
#  [87.97 ]
#  [89.15 ]
#  [88.17 ]
#  [87.86 ]
#  [89.75 ]
#  [89.46 ]
#  [88.62 ]
#  [87.49 ]
#  [87.27 ]
#  [87.47 ]
#  [85.67 ]
#  [84.6  ]
#  [84.14 ]
#  [84.03 ]
#  [82.88 ]
#  [83.34 ]
#  [85.59 ]
#  [86.74 ]
#  [86.36 ]
#  [81.2  ]
#  [79.91 ]
#  [80.07 ]
#  [81.37 ]
#  [83.76 ]
#  [82.38 ]
#  [83.23 ]
#  [82.68 ]
#  [80.   ]
#  [84.18 ]
#  [83.73 ]
#  [83.17 ]
#  [83.04 ]
#  [83.8  ]
#  [79.12 ]
#  [81.47 ]
#  [84.41 ]
#  [86.37 ]
#  [87.8  ]
#  [86.21 ]
#  [87.74 ]
#  [87.48 ]
#  [89.63 ]
#  [88.14 ]
#  [88.55 ]
#  [88.23 ]
#  [93.03 ]
#  [91.94 ]
#  [96.46 ]
#  [96.7  ]
#  [95.07 ]
#  [94.48 ]
#  [93.38 ]
#  [91.75 ]
#  [94.84 ]
#  [92.86 ]
#  [91.77 ]
#  [92.09 ]
#  [92.26 ]
#  [91.98 ]
#  [91.79 ]
#  [92.6  ]
#  [91.2  ]
#  [92.35 ]
#  [92.56 ]
#  [92.16 ]
#  [89.64 ]
#  [89.47 ]
#  [88.68 ]
#  [88.04 ]
#  [85.51 ]
#  [85.85 ]
#  [84.99 ]
#  [84.63 ]
#  [85.6  ]
#  [82.19 ]
#  [86.33 ]
#  [88.61 ]
#  [87.43 ]
#  [87.09 ]
#  [88.49 ]
#  [83.52 ]
#  [81.34 ]
#  [80.18 ]
#  [80.12 ]
#  [78.93 ]
#  [81.43 ]
#  [83.68 ]
#  [84.14 ]
#  [86.04 ]
#  [87.39 ]
#  [86.71 ]
#  [87.61 ]
#  [89.06 ]
#  [88.34 ]
#  [88.97 ]
#  [87.92 ]
#  [87.84 ]
#  [89.94 ]
#  [89.12 ]
#  [89.35 ]
#  [90.11 ]
#  [90.16 ]
#  [90.33 ]
#  [89.58 ]
#  [87.8  ]
#  [89.12 ]
#  [88.09 ]
#  [87.68 ]
#  [87.13 ]
#  [88.19 ]
#  [88.3  ]
#  [87.42 ]
#  [86.92 ]
#  [87.11 ]
#  [86.82 ]
#  [85.94 ]
#  [85.14 ]
#  [84.74 ]
#  [84.53 ]
#  [85.66 ]
#  [85.22 ]
#  [82.01 ]
#  [81.9  ]
#  [81.87 ]
#  [81.44 ]
#  [81.21 ]
#  [81.72 ]
#  [82.75 ]
#  [82.79 ]
#  [82.32 ]
#  [81.83 ]
#  [81.34 ]
#  [80.85 ]
#  [80.02 ]
#  [80.4  ]
#  [80.07 ]
#  [80.01 ]
#  [81.24 ]
#  [80.56 ]
#  [80.04 ]
#  [81.59 ]
#  85.66  85.22  82.01  81.9   81.87  81.44  81.21  81.72  82.75  82.79
#  82.32  81.83  81.34  80.85  80.02  80.4   80.07  80.01  81.24  80.56
#  80.04  81.59  80.91  80.59  79.    72.62  72.26  72.1   71.04  68.88
#  71.3   71.79  70.96  70.92  70.16  70.92  69.73  69.44  69.57  71.02
#  71.33  72.94  74.42  74.07  73.    74.49  73.89  73.02  72.5   72.39
#  72.15  69.99  69.54  70.36  69.32  69.98  69.25  69.59  69.8   69.52
#  71.68  70.47  69.54  69.99  70.07  68.42  69.49  69.74  68.03  66.64
#  66.92  66.02  65.8   67.72  67.52  68.32  67.52  67.92  68.38  67.54
#  67.86  66.62  68.51  68.95  70.33  71.75  70.23  70.58  67.34  67.31
#  66.54  66.1   64.87  67.59  68.52  68.63  70.69  69.99  69.19  66.77
#  69.47  67.91  68.18  68.48  67.39  68.45  69.94  70.48  70.13  70.88
#  70.14  70.74  72.6   72.    71.55  69.87  67.81  67.52  67.21  67.51
#  67.54  67.79  67.86  69.26  67.57  66.7   67.    66.59  66.52  66.74
#  65.68  65.7   64.14  62.98  63.37  65.36  63.95  63.4   65.68  67.15
#  67.82  67.01  65.78  66.56  66.08  69.05  77.97  76.87  76.5   76.3
#  76.58  77.49  78.4   76.45  73.08  68.48  68.51  69.36  69.26  68.49
#  68.94 ]

# %%
#splitting the data into testing and training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#creating a decision tree regressor model
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor().fit(X_train, y_train)

score_train = tree.score(X_train, y_train)
score_test = tree.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.9921663883816922
# Testing Score: 0.5336832845190961

# %%
#score of testing data
regressor = DecisionTreeRegressor(random_state=1)
regressor.fit(X_train, y_train)

from sklearn.model_selection import cross_val_score

score_test = regressor.score(X_test, y_test)
score_train = regressor.score(X_train, y_train)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.9921663883816922
# Testing Score: 0.5336832845190961

# %%
#score of training data
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_test, y_test)

from sklearn.model_selection import cross_val_score

score_train = regressor.score(X_train, y_train)
score_test = regressor.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.6636733884242213
# Testing Score: 0.9952183826442678

# %%
#creating a Linear Regression model
from sklearn.linear_model import LinearRegression
linear = LinearRegression().fit(X_train, y_train)


score_train = linear.score(X_train, y_train)
score_test = linear.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.44189319063789834
# Testing Score: 0.517133179550942

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rf = RandomForestClassifier(n_estimators=200)
rf = RandomForestRegressor().fit(X_train, y_train)
test_score = rf.score(X_test, y_test)
train_score = rf.score(X_train, y_train)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.44189319063789834
# Testing Score: 0.517133179550942

# %%
#pulling the last rows of the predictive dataset
futureX = close.drop(["Prediction"], 1)[:-futureDays]
futureX = futureX.tail(futureDays)
futureX = np.array(futureX)
print(futureX)
# Out:
# [[71.79]
#  [70.96]
#  [70.92]
#  [70.16]
#  [70.92]
#  [69.73]
#  [69.44]
#  [69.57]
#  [71.02]
#  [71.33]
#  [72.94]
#  [74.42]
#  [74.07]
#  [73.  ]
#  [74.49]
#  [73.89]
#  [73.02]
#  [72.5 ]
#  [72.39]
#  [72.15]
#  [69.99]
#  [69.54]
#  [70.36]
#  [69.32]
#  [69.98]
#  [69.25]
#  [69.59]
#  [69.8 ]
#  [69.52]
#  [71.68]
#  [70.47]
#  [69.54]
#  [69.99]
#  [70.07]
#  [68.42]
#  [69.49]
#  [69.74]
#  [68.03]
#  [66.64]
#  [66.92]
#  [66.02]
#  [65.8 ]
#  [67.72]
#  [67.52]
#  [68.32]
#  [67.52]
#  [67.92]
#  [68.38]
#  [67.54]
#  [67.86]
#  [66.62]
#  [68.51]
#  [68.95]
#  [70.33]
#  [71.75]
#  [70.23]
#  [70.58]
#  [67.34]
#  [67.31]
#  [66.54]
#  [66.1 ]
#  [64.87]
#  [67.59]
#  [68.52]
#  [68.63]]

# %%
#predicting using the decision tree model
treePrediction = tree.predict(futureX)
print("Decision Tree prediction =",treePrediction)
# Out:
# Decision Tree prediction = [70.69  69.99  69.33  77.49  69.33  67.91  65.7   68.48  67.39  68.45
#  69.94  70.48  70.13  69.94  70.48  70.74  69.94  72.    71.55  69.87
#  67.165 67.055 67.    67.51  67.54  67.79  67.86  69.26  67.055 76.58
#  67.    67.055 67.165 66.74  65.68  65.7   64.14  65.78  63.37  65.36
#  63.95  63.4   65.68  67.08  67.82  67.08  65.78  65.68  66.08  65.78
#  77.97  76.87  68.52  77.49  76.58  77.49  67.    76.45  76.45  68.48
#  68.51  90.97  66.08  76.87  68.94 ]

# %%
#predicting using the linear regression model
linearPrediction = linear.predict(futureX)

# %%
# predictions using the random forest regression model
rfPrediction = rf.predict(futureX)
print("Random Forest Prediction =", rfPrediction)
# Out:
# Random Forest Prediction = [71.9555     69.71438667 69.33116    73.888675   69.33116    67.5508
#  66.21165    68.1811     67.6714     68.3736     69.4232     71.1513
#  70.6704     69.4232     71.1513     70.4124     69.4232     71.3902
#  71.2197     69.2311     67.117945   67.1059     69.7163     67.4213
#  67.384085   67.5333     67.9083     68.05285    66.9976     73.9142
#  69.77905333 67.1059     67.117945   66.868525   69.3337     66.24075
#  65.892      66.4113     67.1653     65.5535     67.5139     66.4637
#  65.81253333 66.92491333 68.3895     66.92491333 65.82653333 67.7047
#  66.29721333 65.82653333 73.4433     73.4728     68.4518     73.9123
#  73.9834     73.8733     67.99151333 72.99816667 72.99496667 73.9235
#  69.2011     82.7009     66.29721333 73.4728     70.7994    ]

# %%
#plotting the decision tree model predictions
predictions = treePrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("United Airlines' Stock Price Prediction Model (Decision Tree Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["UAL_Close"])
plt.plot(valid[["UAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/decisiontreeUAL.png")

#display the chart
plt.show()
# Out:
# <ipython-input-20-323f9549f8fa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
#plotting the linear regression model predictions
predictions = linearPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("United Airlines' Stock Price Prediction Model (Linear Regression Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["UAL_Close"])
plt.plot(valid[["UAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/linearregressionUAL.png")

#display chart
plt.show()
# Out:
# <ipython-input-21-8c621ff927a6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
#plotting the random forest regresssor model
predictions = rfPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("United Airlines' Stock Price Prediction Model (Random Forest Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["UAL_Close"])
plt.plot(valid[["UAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/randomforestUAL.png")

#display the chart
plt.show()
# Out:
# <ipython-input-22-c07cb0a8ff69>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %% [markdown]
# # Delta Airlines

# %%
#creating initial plot of United Airlines Closing prices as of Dec 31, 2020
sns.set()
plt.figure(figsize=(10, 4))

#create labels
plt.title("Delta Airlines'Stock Price")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(stocks["DAL_Close"])

#save to png
plt.savefig("images/originalcloseDAL.png")

#display chart
plt.show()

# %%
#pulling the array of close prices
close = stocks[["DAL_Close"]]
close.head()
# Out:
#    DAL_Close
# 0      40.21
# 1      40.56
# 2      40.03
# 3      40.15
# 4      39.73

# %%
#creating a variable for the number of future days predicted
futureDays = 65

# %%
#creating a new column to hold the predicted values of close prices
close["Prediction"] = stocks[["DAL_Close"]].shift(-futureDays)
print(close.head())
print(close.tail())
# Out:
#    DAL_Close  Prediction
# 0      40.21       30.61
# 1      40.56       31.34
# 2      40.03       29.78
# 3      40.15       29.01
# 4      39.73       29.56
#      DAL_Close  Prediction
# 751      54.68         NaN
# 752      55.97         NaN
# 753      55.69         NaN
# 754      55.69         NaN
# 755      56.74         NaN
# <ipython-input-26-1194da2c7ffc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close["Prediction"] = stocks[["DAL_Close"]].shift(-futureDays)

# %%
#creating an array and removing the last rows
X = np.array(close.drop(["Prediction"], 1))[:-futureDays]
print(X)
# Out:
# [[40.21]
#  [40.56]
#  [40.03]
#  [40.15]
#  [39.73]
#  [40.24]
#  [38.94]
#  [40.14]
#  [40.68]
#  [41.11]
#  [41.08]
#  [41.85]
#  [40.69]
#  [41.74]
#  [42.62]
#  [42.11]
#  [42.41]
#  [42.35]
#  [42.36]
#  [42.95]
#  [41.07]
#  [39.96]
#  [40.25]
#  [41.06]
#  [41.29]
#  [41.26]
#  [38.79]
#  [37.13]
#  [37.91]
#  [37.91]
#  [37.6 ]
#  [38.  ]
#  [36.46]
#  [34.38]
#  [35.02]
#  [37.04]
#  [36.77]
#  [31.42]
#  [31.98]
#  [30.43]
#  [30.9 ]
#  [30.22]
#  [30.64]
#  [30.76]
#  [29.65]
#  [30.71]
#  [31.93]
#  [34.  ]
#  [33.72]
#  [31.5 ]
#  [31.98]
#  [31.5 ]
#  [31.47]
#  [31.34]
#  [31.76]
#  [31.77]
#  [32.64]
#  [32.81]
#  [32.68]
#  [32.15]
#  [31.06]
#  [32.  ]
#  [31.75]
#  [31.1 ]
#  [30.58]
#  [30.61]
#  [31.34]
#  [29.78]
#  [29.01]
#  [29.56]
#  [30.22]
#  [29.82]
#  [32.84]
#  [33.96]
#  [34.57]
#  [33.51]
#  [32.82]
#  [31.7 ]
#  [31.79]
#  [31.76]
#  [32.54]
#  [31.77]
#  [31.22]
#  [31.14]
#  [30.71]
#  [30.85]
#  [31.99]
#  [30.82]
#  [29.95]
#  [30.1 ]
#  [29.8 ]
#  [27.27]
#  [27.62]
#  [27.67]
#  [27.63]
#  [28.02]
#  [28.95]
#  [28.7 ]
#  [29.09]
#  [29.64]
#  [29.34]
#  [27.18]
#  [27.08]
#  [26.47]
#  [25.67]
#  [25.2 ]
#  [24.97]
#  [24.94]
#  [25.72]
#  [25.94]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#creating a decision tree regressor model
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor().fit(X_train, y_train)

score = tree.score(X_train, y_train)
score_test = tree.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.44189319063789834
# Testing Score: 0.4823025951413441

# %%
#creating a Linear Regression model
from sklearn.linear_model import LinearRegression
linear = LinearRegression().fit(X_train, y_train)

# linear regression scores for training and testing data
score_train = linear.score(X_train, y_train)
score_test = linear.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.38109278828731097
# Testing Score: 0.24012952698067624

# %%
# Random Forest Regressoin model
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rf = RandomForestClassifier(n_estimators=200)
rf = RandomForestRegressor().fit(X_train, y_train)


test_score = rf.score(X_test, y_test)
train_score = rf.score(X_train, y_train)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.38109278828731097
# Testing Score: 0.24012952698067624

# %%
#pulling the last rows of the predictive dataset
futureX = close.drop(["Prediction"], 1)[:-futureDays]
futureX = futureX.tail(futureDays)
futureX = np.array(futureX)
print(futureX)
# Out:
# [[50.51]
#  [49.58]
#  [49.26]
#  [48.78]
#  [49.92]
#  [49.54]
#  [49.8 ]
#  [49.89]
#  [51.07]
#  [51.31]
#  [52.72]
#  [53.73]
#  [53.84]
#  [53.78]
#  [54.8 ]
#  [55.18]
#  [54.9 ]
#  [54.65]
#  [54.55]
#  [54.89]
#  [54.09]
#  [53.46]
#  [54.17]
#  [54.67]
#  [55.19]
#  [54.42]
#  [54.05]
#  [54.31]
#  [54.23]
#  [55.87]
#  [54.4 ]
#  [53.4 ]
#  [53.52]
#  [53.98]
#  [52.95]
#  [53.1 ]
#  [53.48]
#  [52.37]
#  [52.09]
#  [52.9 ]
#  [52.06]
#  [51.62]
#  [52.37]
#  [51.9 ]
#  [52.34]
#  [51.79]
#  [52.36]
#  [52.74]
#  [52.22]
#  [53.5 ]
#  [53.13]
#  [54.65]
#  [53.81]
#  [54.61]
#  [55.4 ]
#  [55.07]
#  [55.21]
#  [54.55]
#  [54.3 ]
#  [52.92]
#  [52.98]
#  [51.47]
#  [52.36]
#  [52.56]
#  [53.05]]

# %%
#predicting using the decision tree model
treePrediction = tree.predict(futureX)
print("Decision Tree prediction =",treePrediction)
# Out:
# Decision Tree prediction = [54.21       55.97       53.72       51.95       53.28       53.93
#  54.26       55.06       53.9        55.9        49.26       56.5
#  55.96       58.145      51.08       56.15       56.59       59.19333333
#  57.305      52.525      51.48       53.84       51.48       53.26
#  53.35       53.06333333 53.62       51.825      57.08       52.55
#  53.06333333 53.         52.85       52.95       57.93       55.82
#  52.05       50.46       51.23       53.85       53.1        47.96
#  50.46       56.42       55.725      56.12       55.725      55.26
#  55.07       56.8        56.365      59.19333333 60.75       59.45
#  59.72       54.53       59.83       57.305      51.14       53.85
#  54.68       55.97       55.725      55.69       56.74      ]

# %%
#predicting using the linear regression model
linearPrediction = linear.predict(futureX)
print("Linear regression Prediction =",linearPrediction)
# Out:
# Linear regression Prediction = [51.01114568 50.44851379 50.25492002 49.96452936 50.65420717 50.42431457
#  50.58160951 50.63605775 51.34993478 51.49513011 52.34815266 52.95918299
#  53.02573085 52.98943202 53.60651216 53.83640476 53.66701022 53.51576508
#  53.45526703 53.66096041 53.17697599 52.79583825 53.22537443 53.52786469
#  53.84245457 53.37661956 53.15277676 53.3100717  53.26167326 54.25384133
#  53.36451995 52.75953942 52.83213708 53.11042813 52.48729818 52.57804526
#  52.80793786 52.13640947 51.96701492 52.45704915 51.94886551 51.68267407
#  52.13640947 51.85206862 52.11826006 51.78552076 52.13035967 52.36025227
#  52.04566239 52.82003747 52.59619468 53.51576508 53.00758144 53.49156586
#  53.96950048 53.76985691 53.85455418 53.45526703 53.3040219  52.46914876
#  52.5054476  51.59192699 52.13035967 52.25135577 52.54779623]

# %%
# predicting using the random forest regressor model
rfPrediction = rf.predict(futureX)
print("Random Forest Prediction =", rfPrediction)
# Out:
# Random Forest Prediction = [54.6064     56.74109667 53.3152     53.1635     54.1292     54.99048667
#  53.82506667 55.2952     54.9183     55.84465    51.6862     55.56501667
#  58.45623667 58.57447548 51.95835    56.17836667 55.08972    59.10267778
#  57.814685   52.2474975  52.2042     53.4579     52.261      54.99269
#  54.72236667 53.10879929 53.0408     51.5847     55.3644     54.30204
#  53.29719929 53.8072     54.0966     53.0484     57.0092     55.60079167
#  53.3008     52.27764167 50.9004     55.1893     52.2946     50.5777
#  52.27764167 56.3398     55.16481333 55.8176     55.22591333 54.0958
#  53.2844     55.2806     55.55777    59.10267778 60.71551762 60.27841111
#  59.03527    55.03024667 57.8201     57.814685   51.268705   55.0274
#  55.8689     53.7861     55.22591333 53.96455    55.24123333]

# %%
#plotting the decision tree model predictions
predictions = treePrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Delta Airlines' Stock Price Prediction Model (Decision Tree Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["DAL_Close"])
plt.plot(valid[["DAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/decisiontreeDAL.png")

#display the chart
plt.show()
# Out:
# <ipython-input-37-623c9ccfe2f5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
#plotting the linear regression model predictions
predictions = linearPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Delta Airlines' Stock Price Prediction Model (Linear Regression Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["DAL_Close"])
plt.plot(valid[["DAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/linearregressionDAL.png")

#display chart
plt.show()
# Out:
# <ipython-input-38-5a3eee9a71bb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
# plotting the random forest regression model
predictions = rfPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Delta Airlines' Stock Price Prediction Model (Random Forest Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["DAL_Close"])
plt.plot(valid[["DAL_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/randomforestDAL.png")

#display the chart
plt.show()
# Out:
# <ipython-input-39-31386e33c05b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
close = stocks[["LUV_Close"]]
close.head()
# Out:
#    LUV_Close
# 0      46.61
# 1      46.41
# 2      46.15
# 3      46.12
# 4      46.28

# %%
#creating a new column to hold the predicted values of close prices
close["Prediction"] = stocks[["LUV_Close"]].shift(-futureDays)
print(close.head())
print(close.tail())
# Out:
#    LUV_Close  Prediction
# 0      46.61       37.61
# 1      46.41       38.24
# 2      46.15       37.10
# 3      46.12       36.86
# 4      46.28       37.55
#      LUV_Close  Prediction
# 751      64.00         NaN
# 752      64.32         NaN
# 753      64.70         NaN
# 754      64.91         NaN
# 755      66.29         NaN
# <ipython-input-41-b885204289a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close["Prediction"] = stocks[["LUV_Close"]].shift(-futureDays)

# %%
#creating a new column to hold the predicted values of close prices
close["Prediction"] = stocks[["LUV_Close"]].shift(-futureDays)
print(close.head())
print(close.tail())
# Out:
#    LUV_Close  Prediction
# 0      46.61       37.61
# 1      46.41       38.24
# 2      46.15       37.10
# 3      46.12       36.86
# 4      46.28       37.55
#      LUV_Close  Prediction
# 751      64.00         NaN
# 752      64.32         NaN
# 753      64.70         NaN
# 754      64.91         NaN
# 755      66.29         NaN
# <ipython-input-42-b885204289a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close["Prediction"] = stocks[["LUV_Close"]].shift(-futureDays)

# %%
#creating an array and removing the last rows
X = np.array(close.drop(["Prediction"], 1))[:-futureDays]
print(X)
# Out:
# [[46.61]
#  [46.41]
#  [46.15]
#  [46.12]
#  [46.28]
#  [46.75]
#  [45.32]
#  [45.8 ]
#  [46.03]
#  [46.39]
#  [45.73]
#  [46.42]
#  [45.26]
#  [45.88]
#  [46.8 ]
#  [45.76]
#  [47.28]
#  [47.89]
#  [47.59]
#  [47.82]
#  [47.44]
#  [47.27]
#  [46.34]
#  [47.73]
#  [48.27]
#  [48.25]
#  [46.81]
#  [45.54]
#  [46.08]
#  [45.6 ]
#  [45.66]
#  [45.58]
#  [43.88]
#  [41.92]
#  [43.22]
#  [44.81]
#  [43.89]
#  [40.01]
#  [41.05]
#  [38.93]
#  [38.85]
#  [38.4 ]
#  [39.53]
#  [39.57]
#  [38.14]
#  [39.93]
#  [41.1 ]
#  [42.79]
#  [41.93]
#  [39.84]
#  [40.16]
#  [39.85]
#  [39.68]
#  [38.8 ]
#  [39.25]
#  [39.13]
#  [39.19]
#  [39.73]
#  [38.99]
#  [38.59]
#  [37.58]
#  [38.49]
#  [38.76]
#  [37.93]
#  [37.5 ]
#  [37.61]
#  [38.24]
#  [37.1 ]
#  [36.86]
#  [37.55]
#  [38.12]
#  [37.52]
#  [39.83]
#  [40.4 ]
#  [42.1 ]
#  [40.61]
#  [40.06]
#  [38.95]
#  [38.94]
#  [39.22]
#  [40.5 ]
#  [39.39]
#  [38.74]
#  [39.17]
#  [37.91]
#  [37.58]
#  [38.81]
#  [37.65]
#  [36.38]
#  [37.06]
#  [36.91]
#  [34.69]
#  [34.46]
#  [34.27]
#  [34.16]
#  [33.81]
#  [34.9 ]
#  [34.71]
#  [35.25]
#  [35.29]
#  [34.99]
#  [33.28]
#  [33.02]
#  [32.72]
#  [31.4 ]
#  [31.58]
#  [30.89]
#  [30.96]
#  [31.79]
#  [32.29]
#  [31.53]
#  [31.66]
#  [32.79]
#  [33.3 ]
#  [33.62]
#  [32.98]
#  [34.13]
#  [34.21]
#  [35.75]
#  [33.25]
#  [32.64]
#  [33.22]
#  [31.57]
#  [32.89]
#  [33.01]
#  [34.3 ]
#  [49.61]
#  [48.76]
#  [48.52]
#  [48.99]
#  [49.08]
#  [47.54]
#  [47.87]
#  [47.86]
#  [45.61]
#  [47.14]
#  [46.48]
#  [46.76]
#  [46.8 ]
#  [46.72]
#  [44.4 ]
#  [45.95]
#  [47.07]
#  [48.78]
#  [49.6 ]
#  [49.39]
#  [50.09]
#  [50.34]
#  [50.9 ]
#  [51.08]
#  [51.14]
#  [51.36]
#  [53.6 ]
#  [52.8 ]
#  [54.37]
#  [54.61]
#  [53.23]
#  [53.08]
#  [52.79]
#  [52.76]
#  [52.68]
#  [52.25]
#  [51.57]
#  [52.39]
#  [52.58]
#  [53.23]
#  [52.48]
#  [52.73]
#  [51.89]
#  [52.49]
#  [52.72]
#  [52.88]
#  [51.86]
#  [51.42]
#  [51.82]
#  [50.95]
#  [49.1 ]
#  [49.15]
#  [47.91]
#  [49.58]
#  [49.91]
#  [54.59]
#  [57.48]
#  [57.87]
#  [58.13]
#  [57.96]
#  [59.2 ]
#  [58.94]
#  [57.68]
#  [57.38]
#  [57.03]
#  [57.33]
#  [59.49]
#  [60.62]
#  [61.05]
#  [61.58]
#  [61.68]
#  [61.18]
#  [61.7 ]
#  [62.45]
#  [62.71]
#  [62.09]
#  [61.65]
#  [62.06]
#  [63.77]
#  [62.5 ]
#  [63.11]
#  [63.05]
#  [63.1 ]
#  [62.43]
#  [62.36]
#  [61.37]
#  [62.98]
#  [62.51]
#  [61.9 ]
#  [61.03]
#  [61.4 ]
#  [61.99]
#  [61.3 ]
#  [60.82]
#  [61.22]
#  [61.33]
#  [60.91]
#  [60.99]
#  [61.01]
#  [60.61]
#  [61.  ]
#  [61.63]
#  [59.68]
#  [59.52]
#  [60.33]
#  [59.09]
#  [58.84]
#  [58.99]
#  [58.99]
#  [58.82]
#  [58.09]
#  [57.79]
#  [57.41]
#  [56.69]
#  [56.52]
#  [58.16]
#  [57.9 ]
#  [58.38]
#  [56.7 ]
#  [52.29]
#  [51.91]
#  [53.56]
#  [53.43]
#  [53.78]
#  [53.9 ]
#  [53.22]
#  [53.08]
#  [53.09]
#  [52.77]
#  [52.53]
#  [53.  ]
#  [53.26]
#  [52.74]
#  [51.86]
#  [51.52]
#  [51.54]
#  [50.88]
#  [50.7 ]
#  [50.37]
#  [51.17]
#  [51.28]
#  [51.91]
#  [53.15]
#  [52.  ]
#  [51.71]
#  [52.37]
#  [52.18]
#  [51.94]
#  [51.35]
#  [50.97]
#  [50.98]
#  [50.48]
#  [50.64]
#  [50.75]
#  [50.9 ]
#  [51.65]
#  [50.96]
#  [51.08]
#  [51.33]
#  [51.49]
#  [52.86]
#  [51.21]
#  [50.32]
#  [50.85]
#  [52.22]
#  [52.19]
#  [52.47]
#  [53.01]
#  [51.7 ]
#  [52.2 ]
#  [52.46]
#  [51.94]
#  [51.56]
#  [52.33]
#  [52.  ]
#  [52.78]
#  [52.24]
#  [52.21]
#  [52.94]
#  [52.83]
#  [53.53]
#  [53.3 ]
#  [53.83]
#  [53.88]
#  [54.98]
#  [54.77]
#  [54.8 ]
#  [55.82]
#  [54.27]
#  [54.89]
#  [55.07]
#  [54.94]
#  [53.5 ]
#  [54.13]
#  [54.85]
#  [55.29]]

# %%
#splitting the data into testing and training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#creating a decision tree regressor model
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor().fit(X_train, y_train)

score = tree.score(X_train, y_train)
score_test = tree.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.38109278828731097
# Testing Score: 0.3582561911942642

# %%
#creating a Linear Regression model
from sklearn.linear_model import LinearRegression
linear = LinearRegression().fit(X_train, y_train)

# linear regression scores for training and testing data
score_train = linear.score(X_train, y_train)
score_test = linear.score(X_test, y_test)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.2442034028496899
# Testing Score: 0.3272793294867621

# %%
# Random Forest Regressoin model
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rf = RandomForestClassifier(n_estimators=200)
rf = RandomForestRegressor().fit(X_train, y_train)


test_score = rf.score(X_test, y_test)
train_score = rf.score(X_train, y_train)

print(f'Training Score: {score_train}')
print(f'Testing Score: {score_test}')
# Out:
# Training Score: 0.2442034028496899
# Testing Score: 0.3272793294867621

# %%
#pulling the last rows of the predictive dataset
futureX = close.drop(["Prediction"], 1)[:-futureDays]
futureX = futureX.tail(futureDays)
futureX = np.array(futureX)
print(futureX)
# Out:
# [[53.26]
#  [52.74]
#  [51.86]
#  [51.52]
#  [51.54]
#  [50.88]
#  [50.7 ]
#  [50.37]
#  [51.17]
#  [51.28]
#  [51.91]
#  [53.15]
#  [52.  ]
#  [51.71]
#  [52.37]
#  [52.18]
#  [51.94]
#  [51.35]
#  [50.97]
#  [50.98]
#  [50.48]
#  [50.64]
#  [50.75]
#  [50.9 ]
#  [51.65]
#  [50.96]
#  [51.08]
#  [51.33]
#  [51.49]
#  [52.86]
#  [51.21]
#  [50.32]
#  [50.85]
#  [52.22]
#  [52.19]
#  [52.47]
#  [53.01]
#  [51.7 ]
#  [52.2 ]
#  [52.46]
#  [51.94]
#  [51.56]
#  [52.33]
#  [52.  ]
#  [52.78]
#  [52.24]
#  [52.21]
#  [52.94]
#  [52.83]
#  [53.53]
#  [53.3 ]
#  [53.83]
#  [53.88]
#  [54.98]
#  [54.77]
#  [54.8 ]
#  [55.82]
#  [54.27]
#  [54.89]
#  [55.07]
#  [54.94]
#  [53.5 ]
#  [54.13]
#  [54.85]
#  [55.29]]

# %%
#predicting using the decision tree model
treePrediction = tree.predict(futureX)
print("Decision Tree prediction =",treePrediction)
# Out:
# Decision Tree prediction = [54.21       53.86       54.07       51.455      52.565      55.41
#  54.26       52.385      53.9        54.67       51.68       56.5
#  56.42       47.5        56.34       51.99       51.76666667 56.16
#  54.64       54.64       53.53       55.38       53.79       55.41
#  50.47       52.57       55.24       54.69       53.46       55.705
#  53.16       52.47       52.85       52.84       52.2        52.17
#  52.05       50.46       51.23       52.195      51.76666667 52.52
#  54.62       56.42       48.56       53.265      52.84       48.11
#  54.81       55.97       59.93       54.78666667 60.01       56.42
#  59.72       59.72       59.83       58.52       58.         54.17
#  54.68       55.97       54.35       55.69       56.74      ]

# %%
#predicting using the linear regression model
linearPrediction = linear.predict(futureX)
print("Linear regression Prediction =",linearPrediction)
# Out:
# Linear regression Prediction = [52.39445789 52.05737136 51.48691723 51.2665145  51.27947937 50.85163877
#  50.73495497 50.52103468 51.03962934 51.1109361  51.5193294  52.32315112
#  51.5776713  51.38968073 51.81752133 51.6943551  51.5387767  51.15631314
#  50.90998067 50.9164631  50.59234144 50.69606037 50.76736714 50.86460364
#  51.35078613 50.90349824 50.98128744 51.14334827 51.2470672  52.13516056
#  51.06555907 50.48862251 50.83219147 51.72028483 51.70083753 51.88234566
#  52.23239706 51.3831983  51.70731996 51.87586323 51.5387767  51.29244423
#  51.79159159 51.5776713  52.08330109 51.73324969 51.7138024  52.18702002
#  52.11571326 52.56948358 52.42038762 52.76395658 52.79636875 53.50943641
#  53.37330531 53.39275261 54.0539608  53.04918365 53.45109451 53.56777831
#  53.48350667 52.55003629 52.95842958 53.42516477 53.71039184]

# %%
# predictions using the random forest regresion model
fPrediction = rf.predict(futureX)
print("Random Forest Prediction =", rfPrediction)
# Out:
# Random Forest Prediction = [54.6064     56.74109667 53.3152     53.1635     54.1292     54.99048667
#  53.82506667 55.2952     54.9183     55.84465    51.6862     55.56501667
#  58.45623667 58.57447548 51.95835    56.17836667 55.08972    59.10267778
#  57.814685   52.2474975  52.2042     53.4579     52.261      54.99269
#  54.72236667 53.10879929 53.0408     51.5847     55.3644     54.30204
#  53.29719929 53.8072     54.0966     53.0484     57.0092     55.60079167
#  53.3008     52.27764167 50.9004     55.1893     52.2946     50.5777
#  52.27764167 56.3398     55.16481333 55.8176     55.22591333 54.0958
#  53.2844     55.2806     55.55777    59.10267778 60.71551762 60.27841111
#  59.03527    55.03024667 57.8201     57.814685   51.268705   55.0274
#  55.8689     53.7861     55.22591333 53.96455    55.24123333]

# %%
#plotting the decision tree model predictions
predictions = treePrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Southwest Airlines' Stock Price Prediction Model (Decision Tree Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["LUV_Close"])
plt.plot(valid[["LUV_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/decisiontreeLUV.png")

#display the chart
plt.show()
# Out:
# <ipython-input-52-3a0372f95fe8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
#plotting the linear regression model predictions
predictions = linearPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Southwest Airlines' Stock Price Prediction Model (Linear Regression Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["LUV_Close"])
plt.plot(valid[["LUV_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/linearregressionLUV.png")

#display chart
plt.show()
# Out:
# <ipython-input-53-07ae4b3ef1b9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
# Plotting the random forest model predictions
predictions = rfPrediction
valid = close[X.shape[0]:]
valid["Predictions"] = predictions
plt.figure(figsize=(10, 6))

#create labels
plt.title("Southwest Airlines' Stock Price Prediction Model (Random Forest Regressor Model)")
plt.xlabel("Days")
plt.ylabel("Close Price USD ($)")
plt.plot(close["LUV_Close"])
plt.plot(valid[["LUV_Close", "Predictions"]])
plt.legend(["Original", "Valid", "Predictions"])

#save to png
plt.savefig("images/randomforestLUV.png")

#display the chart
plt.show()
# Out:
# <ipython-input-54-b4abf214875a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions
